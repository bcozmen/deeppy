# %%
import gym
import matplotlib.pyplot as plt
import numpy as np

# %%
import json
import glob
import os
import pickle

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR
from IPython import display

# %%
from learn_frame import LearningFrame
from models.rl.dqn import DQN, DDQN
from models.rl.sac import Discrete_SAC
from data.envdata import EnvData
from networks.FFN import LayerGenerator
def train(episodes = 500):
    for i in range(episodes):
        while(not lf.train()):
            pass
        if i%25 == 0:
            lf.plot_durations()
    lf.plot_durations(show_result= True)

def train_sac(episodes = 500):
    for i in range(episodes):
        while(not lf.train(duration=False)):
            pass
        lf.durations.append(lf.test())
        if i%25 == 0:
            lf.plot_durations()
    lf.plot_durations(show_result= True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
env = gym.make("CartPole-v1", render_mode="rgb_array")

# %%
q_arch_params = {
    "layers" : [4,128,128,2],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Identity,
    "weight_init" : "uniform"
}
qnet_params = {
    "arch_params" : [q_arch_params],
    "device": device,
    "optimizer": optim.AdamW,
    "lr": 1e-4,
    "weight_decay": 0
}

eps_params = {
    "eps": 0.9,
    "eps_end": 0.05,
    "eps_decay": 1000
}

ddqn_params = {
    "network_params": qnet_params,
    "device": device,
    "criterion": nn.MSELoss,
    "gamma": 0.99,
    "tau": 0.005,
    "eps_params" : None
}

p_arch_params = {
    "layers" : [4,128,128,2],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Softmax,
    "weight_init" : "uniform"
}
pnet_params = {
    "arch_params" : [p_arch_params],
    "device": device,
    "optimizer": optim.AdamW,
    "lr": 1e-4,
    "weight_decay": 0
}

sac_params = {
    "ddqn_params": ddqn_params,
    "pnet_params": pnet_params,
    "alpha_lr" : 1e-4,
    "criterion": nn.MSELoss,
    "target_entropy_coeff": 1.,
    "gamma": 0.99,
    "device" : device
}

# %%
model = Discrete_SAC(**sac_params)
data = EnvData(env, 10000, device= device)
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
durations = []
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = Discrete_SAC(**sac_params)
#       2 data = EnvData(env, 10000, device= device)
#       3 lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
#
# File ~/Desktop/is/deeppy/models/rl/sac.py:33, in Discrete_SAC.__init__(self, ddqn_params, pnet_params, alpha_lr, gamma, device, criterion, target_entropy_coeff)
#      30 self.alpha_optimizer = optim.AdamW(params=[self.log_alpha], lr=alpha_lr, amsgrad = False)
#      32 # Actor
# ---> 33 self.policy_net = Network(**pnet_params)
#      35 # Critic networks
#      36 self.ddqn = DDQN(**ddqn_params)
#
# File ~/Desktop/is/deeppy/networks/FFN.py:105, in Network.__init__(self, arch_params, task, criterion, device, optimizer, lr, weight_decay)
#     103 net = []
#     104 for param in arch_params:
# --> 105 	net += self.layer_generator.generate(**param)
#     106 self.model = nn.Sequential(*net)
#     107 self.to(self.device)
#
# TypeError: networks.FFN.LayerGenerator.generate() argument after ** must be a mapping, not str

# %%
network_params = {
    "layers": [4,128,128,2],
    "dataset": None,
    "task": "reg",
    "hidden_act": nn.ReLU,
    "out_act": nn.Identity,
    "criterion": nn.MSELoss,
    "device": device,
    "optimizer": optim.AdamW,
    "lr": 1e-4,
    "batch_size": None,
    "dropout": None,
    "weight_decay": 0,
    "model_final": False,
    "weight_init": "uniform"
}

eps_params = {
    "eps": 0.9,
    "eps_end": 0.05,
    "eps_decay": 1000
}

ddqn_params = {
    "network_params": network_params,
    "device": device,
    "criterion": nn.MSELoss,
    "gamma": 0.99,
    "tau": 0.005,
    "eps_params" : None
}

# %%
arch_params = {
    "layers" : [4,128,128,2],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Softmax,
    "weight_init" : "uniform"
}
pnet_params = {
    "arch_params" : arch_params
    "device": device,
    "optimizer": optim.AdamW,
    "lr": 1e-4,
    "weight_decay": 0
}

sac_params = {
    "ddqn_params": ddqn_params,
    "pnet_params": pnet_params,
    "alpha_lr" : 1e-4,
    "criterion": nn.MSELoss,
    "target_entropy_coeff": 1.,
    "gamma": 0.99,
    "device" : device
}
model = Discrete_SAC(**sac_params)
data = EnvData(env, 10000, device= device)
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
durations = []

# %%
FFN_args = {
layers : [4,128,128,2],
type : nn.Linear,
hidden_act : nn.ReLU,
out_act : nn.ReLU,
weight_init : "uniform"
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 FFN_args = {
# ----> 2 layers : [4,128,128,2],
#       3 type : nn.Linear,
#       4 hidden_act : nn.ReLU,
#       5 out_act : nn.ReLU,
#       6 weight_init : "uniform"
#       7 }
#
# NameError: name 'layers' is not defined

# %%
train_sac(episodes = 600)

# %%
dqn_params = {
    "network_params": network_params,
    "device": device,
    "criterion": nn.MSELoss,
    "gamma": 0.99,
    "tau": 0.005,
    "eps_params" : eps_params,
    "variant" : "DQN"
}
model = DQN(**dqn_params)
data = EnvData(env, 10000, device= device)
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
durations = []

# %%
train(episodes = 600)

# %%
dqn_params = {
    "network_params": network_params,
    "device": device,
    "criterion": nn.MSELoss,
    "gamma": 0.99,
    "tau": 0.005,
    "eps_params" : eps_params,
    "variant" : "DoubleDQN"
}
model = DQN(**dqn_params)
data = EnvData(env, 10000, device= device)
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
durations = []

# %%
train(episodes = 600)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 train(episodes = 600)
#
# Cell In[3], line 8, in train(episodes)
#       6 def train(episodes = 500):
#       7     for i in range(episodes):
# ----> 8         while(not lf.train()):
#       9             pass
#      10         if i%25 == 0:
#
# File ~/Desktop/is/deeppy/learn_frame.py:34, in LearningFrame.train(self, duration)
#      32 if len(self.data) > self.start_size:
#      33     X = self.data.train_data(self.batch_size)
# ---> 34     self.model.optimize(*X)
#      35 return done
#
# File ~/Desktop/is/deeppy/models/dqn.py:200, in optimize(self, *X)
#
# File ~/Desktop/is/deeppy/models/utils.py:29, in update(self)
#
# KeyboardInterrupt:

# %%
model = DDQN(**ddqn_params)
data = EnvData(env, 10000, device= device)
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
durations = []

# %%
train()
