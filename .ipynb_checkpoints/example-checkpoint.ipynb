# %% [markdown]
# # Introduction to networks, models and data

# %%
import gymnasium as gym
import ale_py

gym.register_envs(ale_py)

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

from learn_frame import LearningFrame
from models.rl.dqn import DQN, DDQN
from models.rl.sac import Discrete_SAC
from data.envdata import EnvData
from data.dataset import DataGetter

from networks.network import Network

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

X = training_data.train_data.unsqueeze(1) / 255
data = DataGetter(X=X, task ="autoencoder", batch_size = 128, normalization = None, device=None)
# Out:
# /home/boz/anaconda3/lib/python3.12/site-packages/torchvision/datasets/mnist.py:76: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")

# %%
latent_size = 10

kernel = 4
stride = 2
padding = 1

e_cnn_arch = {
    "layers" : [1,32,64,128],
    "type" : nn.Conv2d,
    "decs" : [],
    "args" : [{"kernel_size" : kernel, "stride":stride, "padding"  : padding} ],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.ReLU,
    "weight_init" : "uniform"
}

e_flatten_arch = {
    "type" : nn.Flatten
}



e_dense_arch = {
    "layers" : [1152, latent_size * 2],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Identity,
    "weight_init" : "uniform"
}


d_dense_arch = {
    "layers" : [latent_size, 1152],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Identity,
    "weight_init" : "uniform"
}

class ImageShape(nn.Module):
    def __init__(self, shape):
        super(ImageShape, self).__init__()
        self.shape = shape
    def forward(self, x):
        return x.view((-1, *self.shape))


d_image_arch = {
    "type" : ImageShape,
    "args" : [{"shape" : (128,3,3)}]
}

d_cnn_arch1 = {
    "layers" : [128,64,32,16],
    "type" : nn.ConvTranspose2d,
    "decs" : [],
    "args" : [{"kernel_size" : kernel,"stride":stride, "padding"  : padding} ],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.ReLU,
    "weight_init" : "uniform"
}
d_cnn_arch2 = {
    "layers" : [16,1],
    "type" : nn.ConvTranspose2d,
    "decs" : [],
    "args" : [{"kernel_size" : 7,"padding"  : 1, "stride" : 1} ],
    "hidden_act" : nn.Sigmoid,
    "out_act" : nn.Sigmoid,
    "weight_init" : "uniform"
}



arch = [e_cnn_arch, e_flatten_arch]

encoder_params = [e_cnn_arch, e_flatten_arch, e_dense_arch]
decoder_params  = [d_dense_arch, d_image_arch, d_cnn_arch1, d_cnn_arch2]

network_params = {
    "arch_params" : encoder_params, 
    "decoder_params" : decoder_params, 
    "task" :"autoencoder", 
    "device" : device
}

net = Network(**network_params)
print(net)
print("----------")
X,y = data.train_data()
print(X.shape)
#print(f"out shpae : {net(X).shape}")
# Out:
# Network(
#   (criterion): MSELoss()
#   (model): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=1152, out_features=40, bias=True)
#     (8): Identity()
#     (9): Linear(in_features=20, out_features=1152, bias=True)
#     (10): Identity()
#     (11): ImageShape()
#     (12): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (13): ReLU()
#     (14): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (15): ReLU()
#     (16): ConvTranspose2d(32, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (17): ReLU()
#     (18): ConvTranspose2d(16, 1, kernel_size=(7, 7), stride=(1, 1), padding=(1, 1))
# ...

# %%
bvae_params = {
    "network_params" : network_params,
    "latent_size" : latent_size,
    "device" : device,
    "beta" : 0.0001
}

from models.autoencoder.b_vae import B_Vae
model = B_Vae(**bvae_params)
#net = Network(**network_params)
#print(net)
#print("----------")
#print(f"out shpae : {net(data.train_data()).shape}")

# %%
lf = LearningFrame(model, data)

# %%
X = lf.data.train_data()[0][0].unsqueeze(0)
plt.imshow(X[0,0])
plt.show()

X2 = lf.model.predict(X)[0].cpu().detach()
plt.imshow(X2[0,0])
plt.show()

# %%
import numpy as np
for i in range(5000):
    lf.train()
    lf.plot(np.log10((lf.train_loss)), labels = ["l","mse","kl"])
lf.plot(lf.train_loss, show_result= True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 4
#       2 for i in range(5000):
#       3     lf.train()
# ----> 4     lf.plot(np.log10((lf.train_loss)), labels = ["l","mse","kl"])
#       5 lf.plot(lf.train_loss, show_result= True)
#
# File ~/Desktop/is/deeppy/learn_frame.py:133, in LearningFrame.plot(self, datas, labels, show_result)
#     131         plt.plot(means.numpy(), label = label)
#     132 plt.legend()
# --> 133 plt.pause(0.001)  # pause a bit so that plots are updated
#     134 if self.is_ipython:
#     135     if not show_result:
#
# File ~/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:757, in pause(interval)
#     755     if canvas.figure.stale:
#     756         canvas.draw_idle()
# --> 757     show(block=False)
#     758     canvas.start_event_loop(interval)
#     759 else:
#
# ...

# %%
train, test = [], []
for i in range(100):
    lf.train()
# Out:
# 0.1367223560810089

# %%
def train(episodes = 500):
    for i in range(episodes):
        while(not lf.train()):
            pass
        if i%25 == 0:
            lf.plot(lf.rewards)
    lf.plot(lf.rewards,show_result= True)

def train_sac(episodes = 500):
    for i in range(episodes):
        while(not lf.train(metrics=False)):
            pass
        c, r = lf.test()
        lf.durations.append(c)
        lf.rewards.append(r)
        if i%25 == 0:
            lf.plot(lf.rewards)
    lf.plot(lf.rewards,show_result= True)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

env = gym.make("ALE/SpaceInvaders-v5")
env.action_space.shape

obs, act = env.observation_space.shape[-1], env.action_space.n


t1 = torch.tensor(env.reset()[0], dtype = torch.float32).T.unsqueeze(0)
t2 = torch.tensor(env.reset()[0], dtype = torch.float32).T.unsqueeze(0)

t = torch.cat((t1,t2))

# %% [markdown]
# # Networks
#
# Networks are the basic building blocks of deeppy, defined as:
#
# ```python
# def __init__(self, arch_params, task = "reg", criterion = nn.MSELoss, device = None,
# 					   optimizer = optim.AdamW, lr = 0.01, weight_decay = 0 , scheduler_params = None):
# ```
#
# Every network at least consists of:
#
# 1) model     -> nn.Sequential neural network | (arch_params)
# 2) optimizer -> torch.optim optimizer        | (optimizer, lr, weight_decay)
# 3) scheduler -> deeppy.utils.Scheduler       | (scheduler_params)
#
# And these methods:
#
# 1) optimize(X) - given a dataset X and defined criterion, perform one step optimization
# 2) forward(X)  - given a dataset X, computer f(x)
# 3) autoencode(X), decode(X) - for autoencoder architectures encode-decode

# %% [markdown]
# ## deeppy.networks.network.LayerGenerator
#
# An architecture is defined by arch_params parameter, that uses a LayerGenerator.
# A LayerGenerator generates repetative layers given layer size. For example with the following parameters
#
# ```python
# layer_generator_params = {
#     "layers" : [obs,64,32,16],
#     "type" : nn.Conv2d,
#     "decs" : [nn.MaxPool2d],
#     "args" : [{"kernel_size" : 4} , {"kernel_size" : 2}],
#     "hidden_act" : nn.ReLU,
#     "out_act" : nn.Sigmoid,
#     "weight_init" : "uniform"
# }
# ```
#
# We will get a CNN network with 3 layers, where every layer has a Conv2d with kernel size 4 followed by MaxPool2d kernel size 2 and a ReLU layer. The output layer of this network is sigmoid

# %%
cnn_arch = {
    "layers" : [obs,64,32,16],
    "type" : nn.Conv2d,
    "decs" : [nn.MaxPool2d],
    "args" : [{"kernel_size" : 4} , {"kernel_size" : 2}],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Sigmoid,
    "weight_init" : "uniform"
}

net = Network(arch_params = [cnn_arch])
print(net)
print("----------")
print(f"inp shape : {t.shape}")
print(f"out shpae : {net(t).shape}")
# Out:
# Network(
#   (criterion): MSELoss()
#   (model): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(64, 32, kernel_size=(4, 4), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Conv2d(32, 16, kernel_size=(4, 4), stride=(1, 1))
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Sigmoid()
#   )
# )
# ----------
# inp shape : torch.Size([2, 3, 160, 210])
# out shpae : torch.Size([2, 16, 17, 23])

# %% [markdown]
# ### We can define multiple types of layers and add them consecutively.
#
# Lets use the CNN architecture, flatten it and pass it through some Linear layers

# %%
flatten_arch = {
    "type" : nn.Flatten
}

dense_arch = {
    "layers" : [16*17*23,128,32,16*17*23],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Identity,
    "weight_init" : "uniform"
}

network_params = [cnn_arch, flatten_arch, dense_arch]
net = Network(arch_params = network_params)
print(net)
print("----------")
print(f"inp shape : {t.shape}")
print(f"out shpae : {net(t).shape}")
# Out:
# Network(
#   (criterion): MSELoss()
#   (model): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(64, 32, kernel_size=(4, 4), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Conv2d(32, 16, kernel_size=(4, 4), stride=(1, 1))
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Sigmoid()
#     (9): Flatten(start_dim=1, end_dim=-1)
#     (10): Linear(in_features=6256, out_features=128, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=128, out_features=32, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=32, out_features=6256, bias=True)
#     (15): Identity()
#   )
# )
# ----------
# inp shape : torch.Size([2, 3, 160, 210])
# out shpae : torch.Size([2, 6256])

# %% [markdown]
# ### You can also create your own layers
#
# Let's convert the dense layer output back to an image

# %%
class Image(nn.Module):
    def __init__(self, shape = (16,17,23)):
        super(Image, self).__init__()
        self.shape = shape

    def forward(self, x):
        return x.view((-1, *self.shape))


image_arch = {
    "type" : Image,
    "args" : [{"shape" : (16,17,23)}]
}
network_params = [cnn_arch, flatten_arch, dense_arch, image_arch]
net = Network(arch_params = network_params)
print(net)
print("----------")
print(f"inp shape : {t.shape}")
print(f"out shpae : {net(t).shape}")
# Out:
# Network(
#   (criterion): MSELoss()
#   (model): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(64, 32, kernel_size=(4, 4), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Conv2d(32, 16, kernel_size=(4, 4), stride=(1, 1))
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Sigmoid()
#     (9): Flatten(start_dim=1, end_dim=-1)
#     (10): Linear(in_features=6256, out_features=128, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=128, out_features=32, bias=True)
#     (13): ReLU()
#     (14): Linear(in_features=32, out_features=6256, bias=True)
#     (15): Identity()
#     (16): Image()
#   )
# )
# ----------
# inp shape : torch.Size([2, 3, 160, 210])
# out shpae : torch.Size([2, 16, 17, 23])

# %% [markdown]
# # Datasets
#
# There are 2 supported type data structures for now. Every dataset structure has
#
# def train_data() that returns training data with labels
#
#     1) Gym environment
#         Given a gym environment, this structure handles the environment-model interactions and the replay buffer
#     2) X_train, y_train, X_test, y_test labeling

# %%
env = gym.make("LunarLander-v3", render_mode="rgb_array")
obs, act = env.observation_space.shape[-1], env.action_space.n

data = EnvData(env, buffer_size = 200000, device= device)

# %% [markdown]
# # Models
#
# Lets try to learn LunarLander with Discrete Soft Actor-Critic method. We will need 2 different networks, Q-Networks and a policy network
#
# The SAC algorithm uses a policy network and a version of DoubleDQN
#
# DoubleDQN algorithm uses 2xDQN algorithm
#
# And each DQN algorithm has 2 Q-Networks
#
# Thus leaving us with 4 identical Q-Networks in total

# %%
#Define Q-Network architecture
q_arch_params = {
    "layers" : [obs,128,128,act],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Identity,
    "weight_init" : "uniform"
}

#Define Q-Network (including optimizers)
qnet_params = {
    "arch_params" : [q_arch_params],
    "device": device,
    "optimizer": optim.AdamW,
    "lr": 2*1e-4,
    "weight_decay": 0
}

#Define DDQN
ddqn_params = {
    "network_params": qnet_params,
    "device": device,
    "criterion": nn.MSELoss,
    "gamma": 0.99,
    "tau": 0.005,
    "eps_params" : None
}

#Define policy net architecture
p_arch_params = {
    "layers" : [obs,128,128,act],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Softmax,
    "weight_init" : "uniform"
}

#Define Policy network
pnet_params = {
    "arch_params" : [p_arch_params],
    "device": device,
    "optimizer": optim.AdamW,
    "lr": 2*1e-4,
    "weight_decay": 0
}


#Defin SAC
sac_params = {
    "ddqn_params": ddqn_params,
    "pnet_params": pnet_params,
    "alpha_lr" : 2*1e-4,
    "criterion": nn.MSELoss,
    "target_entropy_coeff": 1.,
    "gamma": 0.99,
    "device" : device
}
model = Discrete_SAC(**sac_params)

# %%
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
for i in range(500):
    while(not lf.train(metrics=False)):
        pass
    c, r = lf.test()
    lf.durations.append(c)
    lf.rewards.append(r)
    if i%25 == 0:
        lf.plot(lf.rewards)
lf.plot(lf.rewards,show_result= True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 3
#       1 lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
#       2 for i in range(500):
# ----> 3     while(not lf.train(metrics=False)):
#       4         pass
#       5     c, r = lf.test()
#
# File ~/Desktop/is/deeppy/learn_frame.py:43, in LearningFrame.train(self, metrics)
#      41 if len(self.data) > self.start_size:
#      42     X = self.data.train_data(self.batch_size)
# ---> 43     self.model.optimize(*X)
#      44 return done
#
# File ~/Desktop/is/deeppy/models/rl/sac.py:62, in Discrete_SAC.optimize(self, *X)
#      60 # Update Actor
#      61 current_alpha = copy.deepcopy(self.alpha)
# ---> 62 actor_loss, action_probs, log_pis = self.policy_loss(states, current_alpha.to(self.device))
#      64 # Alpha loss
# ...
