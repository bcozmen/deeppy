# %%
import gymnasium as gym
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim

# %%
from learn_frame import LearningFrame
from models.rl.dqn import DQN, DDQN
from models.rl.sac import Discrete_SAC
from data.envdata import EnvData

# %%
def train(episodes = 500):
    for i in range(episodes):
        while(not lf.train()):
            pass
        if i%25 == 0:
            lf.plot(lf.rewards)
    lf.plot(lf.rewards,show_result= True)

def train_sac(episodes = 500):
    for i in range(episodes):
        while(not lf.train(metrics=False)):
            pass
        c, r = lf.test()
        lf.rewards.append(r)
        if i%25 == 0:
            lf.plot(lf.rewards)
    lf.plot(lf.rewards,show_result= True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
env = gym.make("CartPole-v1", render_mode="rgb_array")
env = gym.make("LunarLander-v3", render_mode="rgb_array")
env.action_space.shape

obs, act = env.observation_space.shape[0], env.action_space.n
# Out:
# ---------------------------------------------------------------------------
# VersionNotFound                           Traceback (most recent call last)
# Cell In[3], line 21
#      19 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      20 env = gym.make("CartPole-v1", render_mode="rgb_array")
# ---> 21 env = gym.make("LunarLander-v3", render_mode="rgb_array")
#      22 env.action_space.shape
#      24 obs, act = env.observation_space.shape[0], env.action_space.n
#
# File ~/anaconda3/lib/python3.12/site-packages/gym/envs/registration.py:569, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     563         logger.warn(
#     564             f"Using the latest versioned environment `{new_env_id}` "
#     565             f"instead of the unversioned environment `{id}`."
#     566         )
#     568     if spec_ is None:
# --> 569         _check_version_exists(ns, name, version)
#     570         raise error.Error(f"No registered env with id: {id}")
#     572 _kwargs = spec_.kwargs.copy()
#
# File ~/anaconda3/lib/python3.12/site-packages/gym/envs/registration.py:248, in _check_version_exists(ns, name, version)
#     245     version_list_msg = ", ".join(f"`v{spec_.version}`" for spec_ in env_specs)
#     246     message += f" It provides versioned environments: [ {version_list_msg} ]."
# --> 248     raise error.VersionNotFound(message)
#     250 if latest_spec is not None and version < latest_spec.version:
#     251     raise error.DeprecatedEnv(
#     252         f"Environment version v{version} for `{get_env_id(ns, name, None)}` is deprecated. "
#     253         f"Please use `{latest_spec.id}` instead."
#     254     )
#
# VersionNotFound: Environment version `v3` for environment `LunarLander` doesn't exist. It provides versioned environments: [ `v2` ].

# %%
q_arch_params = {
    "layers" : [obs,128,128,act],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Identity,
    "weight_init" : "uniform"
}
qnet_params = {
    "arch_params" : [q_arch_params],
    "device": device,
    "optimizer": optim.AdamW,
    "lr": 2*1e-4,
    "weight_decay": 0
}

eps_params = {
    "eps": 0.9,
    "eps_end": 0.05,
    "eps_decay": 1000
}

ddqn_params = {
    "network_params": qnet_params,
    "device": device,
    "criterion": nn.MSELoss,
    "gamma": 0.99,
    "tau": 0.005,
    "eps_params" : None
}

p_arch_params = {
    "layers" : [obs,128,128,act],
    "type" : nn.Linear,
    "decs" : [],
    "args" : [],
    "hidden_act" : nn.ReLU,
    "out_act" : nn.Softmax,
    "weight_init" : "uniform"
}
pnet_params = {
    "arch_params" : [p_arch_params],
    "device": device,
    "optimizer": optim.AdamW,
    "lr": 2*1e-4,
    "weight_decay": 0
}

sac_params = {
    "ddqn_params": ddqn_params,
    "pnet_params": pnet_params,
    "alpha_lr" : 2*1e-4,
    "criterion": nn.MSELoss,
    "target_entropy_coeff": 1.,
    "gamma": 0.99,
    "device" : device
}

# %%
model = Discrete_SAC(**sac_params)
data = EnvData(env, 20000, device= device)
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
durations = []

# %%
train_sac(episodes=500)

# %%
dqn_params = {
    "network_params": qnet_params,
    "device": device,
    "criterion": nn.MSELoss,
    "gamma": 0.99,
    "tau": 0.005,
    "eps_params" : eps_params,
    "variant" : "DQN"
}
model = DQN(**dqn_params)
data = EnvData(env, 10000, device= device)
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
durations = []

# %%
train(episodes=10)
# Out:
# /home/boz/anaconda3/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 train(episodes=10)
#
# Cell In[3], line 3, in train(episodes)
#       1 def train(episodes = 500):
#       2     for i in range(episodes):
# ----> 3         while(not lf.train()):
#       4             pass
#       5         if i%25 == 0:
#
# File ~/Desktop/is/deeppy/learn_frame.py:30, in LearningFrame.train(self, metrics)
#      28 self.model.train()
#      29 if isinstance(self.data, EnvData):
# ---> 30     done, reward = self.data.collect(self.model)
#      31     self.duration +=1
#      32     self.reward += reward
#
# File ~/Desktop/is/deeppy/data/envdata.py:38, in EnvData.collect(self, model)
#      35 action = model.predict(self.state, self.env.action_space.sample)
#      36 observation, reward, termination, truncation, data = self.env.step(action.item())
# ---> 38 ret_reward = torch.clone(reward)
#      40 done = (termination or truncation)
#      42 reward = torch.tensor([reward], device=self.device).unsqueeze(0)
#
# TypeError: clone(): argument 'input' (position 1) must be Tensor, not float

# %%
dqn_params = {
    "network_params": qnet_params,
    "device": device,
    "criterion": nn.MSELoss,
    "gamma": 0.99,
    "tau": 0.005,
    "eps_params" : eps_params,
    "variant" : "DoubleDQN"
}
model = DQN(**dqn_params)
data = EnvData(env, 10000, device= device)
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
durations = []

# %%
train(episodes=700)

# %%
model = DDQN(**ddqn_params)
data = EnvData(env, 10000, device= device)
lf = LearningFrame(model, data, batch_size = 128, start_size = 128)
durations = []

# %%
train()
